# %%
# Генераторы
G1=int(readline())
G2=int(readline())
# Секция шин
S1=int(readline())
S2=int(readline())
S3=int(readline())
S4=int(readline())
# Кабельные линии
VL1=int(readline())
VL2=int(readline())
# Воздушные линии
KL1=int(readline())
KL2=int(readline())
KL3=int(readline())
# Закрытие файла
f.close()
