# %%
import numpy as np

# %%
def f(x):
    return x**3 + 2.5*x**2 - 6.5*x - 15

def f_derivative(x):
    return 3*x+5*x-6.5

def phi(x, lambda_value):
    return x-(lambda_value*f(x))

def lambda_check(lambda_value, x_value):
    d = f_derivative(x_value)
    if (0 < lambda_value*d < 2) and (lambda_value != 0) and (np.sign(lambda_value) == np.sign(d)):
        return True
    else:
        return False

# %%
eps_value = 0.1
lambda_candidates = np.arange(-2, 3, 0.05)

# %%
x_prev = 4 # можно попробовать другой
answer = None
while True:
    # 1. при заданном значении x_prev найти такую лямбду, при которой lambda_check == True,
    #   т.е. по идее значения лямбды нужно подобрать
    # 2. найти значение k+1 просто подставив x и лямбду в phi, это будет x_next
    # 3. сравнить x_prev и выход phi:
    #    if abs(x_next - x_prev) < eps_value: -- успех!
    #       answer = (lambda, x_prev)
    #       break
    #    x_prev = x_next

# следить за временем выполнения и оперативной памятью!
# Out:
#   Cell In[1], line 13
#     # следить за временем выполнения и оперативной памятью!
#                                                            ^
# SyntaxError: incomplete input
