# %%
R1=float(input())
R2=float(input())
R3=float(input())
R4=float(input())
R5=float(input())
R6=float(input())
R7=float(input())
R8=float(input())
R284=R2+R8+R4 #108
R67=1/(1/R6+1/R7) #26.56
R28467=1*(1/R284+1/R67) # 21.32
R1328467=R1+R3+R28467 #126.32
RO=1/(1/R5+1/R1328467) #53.23
ptint(RO)
# Out:
#  24
#  57
#  81
#  13
#  92
#  45
#  66
#  38
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 14
#      12 R1328467=R1+R3+R28467 #126.32
#      13 RO=1/(1/R5+1/R1328467) #53.23
# ---> 14 ptint(RO)
#
# NameError: name 'ptint' is not defined

# %%
# Правильный ответ 53.25
